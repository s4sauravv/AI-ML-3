# %% [markdown]
# #  Logistic Regression Boxplot

# %% [markdown]
# # Logistic Regression ->
#
#
#
# Logistic Regression is one of the supervised machine learning algorithms and it can be used for classification ? and what kind of a classification ? binary classification . it is used for solving classification problem that to binary classification.
#
#
#
#
#
# Q- What is Binary ?
#
#
#
#
# Ans - Binary is Basically will have only two outcome . means 0 or 1 like , pass of fail , True or False .
#
#
#
# So, to identify wheather covid positive or negative wheather you are going to fail . so preidct this kind of class we use logistic regression . these are the categories.
#
#
#
# To predict such kind of category ,such kind of classes we use logistic Regression.

# %% [markdown]
# # How its Going to Work
#
#
# Why its  again called regression . if it is a classification why ther are calling it as  a regression   . it is because it also use   -=mx+c only but differently

# %% [markdown]
# #  One more possible question in the interview is that in order to predict binary data , primary category , or classification  Why cant we use Linear Regression.
#
#
#
#
# Ans -  If i am going to hospital asking a doctor based on the symptoms what ever i have , cough ,cold , fever, whatever it is . wheather i am asking i am covid positive or Not . sippose Docter is a model Just by looking hewill predict something either positive or negative . He cannot stake in between  .
#
#
#
#
# So if i using linear regression for that linear regression will give result in continious data . we also seen that .  This reason we use logistic regression for  classification problem .

# %% [markdown]
# #  Logistic Still uses mx+c , How to works here and what is the idea here .
#
#
#
#
# So , logistic regression use one fucntion name called , Sigmoid Fucntion . i will explain in detail manner , what it does .
#
#
#
#
# # So, What happen behind the scene .
#
#
#
# Sigmoid Function also called as logit function..
#
#
# ![Saurav.png](attachment:Saurav.png)
#
#
#
#
#
# So , as i said i will uses mx+c only , so this is going to let say it is going to give me  0.59 , take any number between 0 and 1 only . what its sigmoid function can do at high level. it will take these number what ever it is going to give linear regression . so this number will check wheather it is aboce this line 0.5 . i am going to classify the positive if it is giving 0.30 anything below that 0.5 so this will classify as negative ..
#
#
#
#
#
#
# # Sigmoid Fucntion -
#
#
#
# Will convert these number into calsses .
#
#
#
# It will predict  either 0 or 1 or you can say positive or negative , or pass or fail. so this is how sigmoid function will help us to classify these continious data in to categorical number . so that why we use sigmoid fucntion.
#
#
#
#
# So , Thats is the idea behind this logistic regression at hight level take that number convert into classes.

# %% [markdown]
# # How we can write Sigmoid Function
#
#
#
#
#
#
# ![image.png](attachment:image.png)
#
#
# what is x here = x =mx+c

# %% [markdown]
# #  Evaluation of a Classification model
#
#
# Now, Lets understand How are we going to evaluate these Classification Model.
#
#
#
#
#
#
# Using of metrics in linear Regression what are the metrics ,MAE ,MSE,RMSE ,.score , R2.Score. this all are metrics is linear regression. why we  use these metrics How good is the model , How bad is the model but the we do not use this method in classification method.
#
#
#
#
#
# --> For Classification Model we have all together different metrics . different evaluation tools we can not mix and match never ever .
#
#
#
#
#
#
#
# Then  what are the classification method tools for evaluation tools or what metrics we use and how to understand  .
#
#
#
#
# - Accuray
#
#
# - Recall
#
#
#
# - Precision
#
#
#
#
# - F1 Score
#
#
# - Specify
#
#
#
#
# - AUC (Area under Curve)
#
#
#
#
# - ROC (Reciever operator characterstics )
#
#
#
#
#
#
#
#
# In order to understand all metrics first we have to understand confusion Metric.

# %% [markdown]
# # Confusion Matrix -
#
#
#
# Lets assume that 100 people visited hospital you have give a test . so you have given a blood sample .for
#
#
# -  Glucose Level
#
#
# - BP
#
#
# - Sugar
#
#
#
# And you see some numbers for for everything . our body contains number only . with those numbers doctor predicted he looked the data of all 100 people . and he predicted report,report has not come yet . before report doctor has predicted positive , negative ...
#
#
#
#
#
# After two days report has come of 100 people report can never lie prediction can wrong . report have also positive ,negative list.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Q - > How Good Doctor Prediction .
#
#
#
#
#
#
# So what we can do compare actual with predicted . we we compare  beacause we need to know how good is the doctor .
#
#
#
#
#
#
#
# Overall i have to tell how good is the doctor . so we hace to know how many doctor can predict correct and how many doctor can predict wrong .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Correctly Predicted means 100%
# wrong predicted means 0%
#
#
#
#
#
#
# How are going to put in terms of a table to understand this . so that is what we are going to do that were your confusion metrics comes into picture.
#
#
#
#
#
# ![love.jpg](attachment:love.jpg)
#
#
#
#
#
#
#
#
# Where the terms have the meaning
#
#
# TP - A result that was predicted as positve by the classification model and also is positive .
#
#
#
#
#
# TN - A result that was predicted as negative by the classification model and also is negative
#
#
#
#
#
# FP - A result that was predicted as positive by the classification model but actually is negative
#
#
#
#
#
# FN - A result was predicted as negative bu the classification model but actually is positive.
#
#
#
#
# The Creadibility of the model is based on how many correct prediction did the model do .
#
#
#
#
#
#
#
# --> So , Now  This is the confusion metric . this is how we need to interpret . Now based on the confusion metric we are going to discuss metric.
#
#
#
#
#
#
#
#
# The Creadibility of the model is based on how many correct prediction did the model do .

# %% [markdown]
# #  Accuracy -
#
#
#
#
#
# The Mathematically formula is  :
#
#
#
# Accuracy = (TP+TN)/(TP+TN+FP+FN)
#
#
#
#
# Accuracy is the measure of how often a classification system gets the correct answer. It's calculated by dividing the number of correct classifications by the total number of classifications made.

# %% [markdown]
# #  Recall Or Senstivity
#
#
#
#
# he Mathematically formula is :
#
#
# ![image.png](attachment:388fd642-3b59-49e7-84c9-fbbeb490f57d.png)
#
#
#
# Definition:
#
# Recall measures how well a model identifies positive cases. Specifically, it shows the proportion of actual positive cases that were correctly predicted by the model. In other words, it tells us how many of the total positive cases were correctly identified.
#
#
#
# Example:
#
# If a model correctly identifies 50 cancer patients (TP) but fails to identify 200 cancer patients (FN), then:
#
#
# ![image.png](attachment:c0e67626-2521-42b0-b21a-bb3781b9bc6d.png)
#
# This means the model was able to correctly identify 20% of the actual cancer patients.

# %% [markdown]
# # Precision -- >
#
# Definition:
#
# Precision measures how many of the predicted positive cases are actually positive. It tells us the accuracy of the positive predictions made by the model.
#
# Mathematical formula:
#
# ![image.png](attachment:61f4803a-873e-4cb9-a80e-117a17c24378.png)
#
# Example:
#
# If the model identifies 50 people as cancer patients (TP) but also incorrectly labels 100 people as cancer patients when they are not (FP), then:
#
#
#
# ​
# ![image.png](attachment:15febe7f-afd2-4df7-88de-fd5ba188435f.png)
#
# This means the model has a precision of 33%, indicating that only 33% of the predicted positive cases were actually positive.

# %% [markdown]
# Hey Sir, you mentioned precision, recall, and accuracy. Which one should we consider here? Which one is better? Do we need to know all of them? What is the best one?
#
# The choice depends on the problem we're solving.
#
# If you're confused about whether to rely on recall or accuracy, keep in mind that we have accuracy, recall, and precision, and they all give different results. Which one should you choose?
#
# In such cases, we use a trade-off measure called the F1 Score.
#
# Trade-off
# The F1 Score is a trade-off between precision and recall. It helps us find a balance when neither precision nor recall alone is sufficient. The F1 Score combines both metrics into a single score.
#
# F1 Score
# From previous examples, we can see that we need a metric that considers both precision and recall to evaluate a model effectively. One such metric is the F1 Score.
#
# The F1 Score is defined as the harmonic mean of precision and recall.
#
# The mathematical formula is:
#
# ![image.png](attachment:19578c0a-7096-4e2c-a1d4-a28ae510beda.png)
#
# This formula helps us stay in between, balancing precision and recall.

# %% [markdown]
# # Why are we measuring recall and precision? What is the impact? How significant is the impact? What are we trying to achieve here? Let's take a real-time example.
#
# ![LUCVKY.png](attachment:LUCVKY.png)
#
#
#
#
#
#
# Recall: 100 people visited the hospital, and this is the prediction made by the model or doctor. The doctor predicted that 15 of these people do not have coronavirus; they are negative. The doctor, despite the symptoms, said "No, no, no, you don’t have coronavirus; you’re good to go." However, when the results came in, it turned out that these 15 people were actually positive. By the time the results were known, these individuals had already started attending weddings, events, etc., spreading the virus. This is an example of a Type II Error, where the model failed to correctly identify positive cases.
#
#
#
# So we have good recall rate when we are doing with disease related example which speread person to person .
#
#
#
#
#
# Precision --Lets take investment Example  -
#
# In investments, experts often advise businessmen to invest in a particular area, suggesting that they will make a profit if they do. They might be positive about the business prospects. For example, you invest 1 crore based on their advice, but after investing, no customers come to your business, and your business starts to incur losses. In this case, the expert's prediction was incorrect.
#
# That change base on what type of dataset you used .

# %% [markdown]
# # Specificity Or True Negative rate.
#
#
# Specificity measures how well a model correctly identifies negative cases.
#
# Mathematically,
# ![image.png](attachment:029cee4c-096c-4fab-9ec2-21543d86eff1.png)
#
#
#
# In other words, it tells you how good the model is at predicting things that are truly negative.
#
# False Positive Rate is the opposite of specificity. It's calculated as:
# False Positive Rate = ![image.png](attachment:617e0946-aea7-4752-85b2-214508019b20.png)
#
#
#
#
#
#
#
# Similarly, False Positive rate can be defined as: (1- specificity) Or,
#
#
#
#
# FP/(TN+FP)

# %% [markdown]
# # ROC(Receiver Operator Characteristic)
#
# ![Saurav%20Here.jpg](attachment:Saurav%20Here.jpg)
#
#
#
# it depend on the situation again . this threshold will change . How to basically see . what kind of problem we are solved . How you need to set that Threshold . we dont need to set that threshold but it will change according to threshold , numbers will change
#
#
#
#
# Acording to threshold numberss will change . How much they are going to change  at what threshold .
#
#
# Lets Under Stand with this ROC.
#
#
# ![Screenshot%20%28192%29.jpg](attachment:Screenshot%20%28192%29.jpg)
#
#
# - The horizontal lines represent the various values of thresholds ranging from 0 to 1.
#
#
#
# - Let’s suppose our classification problem was to identify the obese people from the given data.
#
#
#
# - The green markers represent obese people and the red markers represent the non-obese people.
#
#
#
# - Our confusion matrix will depend on the value of the threshold chosen by us
#
#
# - For Example, if 0.25 is the threshold then
#
#
#
# - TP(actually obese)=3
#
#
#
# - TN(Not obese)=2
#
#
#
# - FP(Not obese but predicted obese)=2(the two red squares above the 0.25 line)
#
#
#
#
# - FN(Obese but predicted as not obese )=1(Green circle below 0.25line )

# %% [markdown]
# But we have a confusion!!
#
#
#
#
# Let’s suppose that we used different classification algorithms, and different ROCs for the corresponding algorithms have been plotted. The question
# is: which algorithm to choose now? The answer is to calculate the area under each ROC curve

# %% [markdown]
# # AUC(Area Under Curve)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Student of DataScince - 
#Student of DatarTrained -Saurav
#Date -26-09-2022
#Time - 16:12
