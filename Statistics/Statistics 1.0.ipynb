# %% [markdown]
# # Introduction to statistics
#
# Numbers that have been collected in order to provide information about something

# %% [markdown]
# # 1 - Types of Statistics
#
# #       A- Descriptive Statistics
# #       B- Inferential Statistics

# %% [markdown]
# # A->> Descriptive Statistics- Discriptive Statistics usually apply on whole population .and then get some result like mean,median, and average .
# Like Example - we have a class and i want to find the average marks of whole student in subject maths . then what we we will do . we conduct a exam in a class and check the marks of whole student then calculate the mean and average of the class then we get what we want .
#
# Basically when we apply a Statistics to whole population and get a result this is known as Descriptive Statistics.

# %% [markdown]
# # B->> Inferential Statistics - Inferential Statistics usually apply on some sample population . and then we got some result and we assume the  result to the whole population.
#
# Like Example - In US . US try to make a covid vaccine . and he test a vaccine in 40000 people and get the effectiveness of the vaccine is 95% and the vaccine company assume that . when we apply only 40000 people then we get a 95% result . its means when we apply on 30 crore population we get same result like 40000.This is Known as inferential statistics.
#
#
# Basically when we apply statistics to a Sample Population . and the we get a  result on sample population and we assume this result will apply same as sample population this is know as Inferential Statistics.

# %% [markdown]
# # 2- Analytics Methodology and How industry use statistics

# %% [markdown]
# A- Wheather Forecasting
#
#
#
# B- Given Insurence
#
#
#
# C- Stock Market
#
#
#
#
# D- Drug effectiveness before releasing to the public
#
#
#
# E- Diseased Survivel Probablity
#
#
#
#
# F- Election Winning and Exit poll pridiction
#
#
#
#
# G- Load approval and Fraud detection
#
#
#
#
# H- Netflix and Amazon recommendation\
#
#
#
#
#
# I- New campaign effictiveness

# %% [markdown]
# # 3- Population and Sample
#
#
# Population- Population Means the total number of population present .
#
# Sample- Sample means we take few number of population as sample .

# %% [markdown]
# # 4-  Parameter and Statistics ('Mean','Median','Mode')

# %%
#Mean (Using Stats)
import statistics as st
import pandas as pd
import numpy as np

# %%
x=[10,20,30,40,35,40,40,50,50,50,50,45,50,60,70,80]

# %%
print(st.mean(x))

# %%
#Using Pandas 
x=pd.DataFrame(x)

#Lets Remember one thing when you convert a list into DataFrame then . 
#statistics not working. then you again conver to the list.

# %%
x.mean()

# %%
#Median
print(st.median(x))

# %%
#mode
st.mode(x)

# %% [markdown]
# # 5- Uses of Variable Dependent and  independent variable.

# %% [markdown]
# So what is Variable - Varible are the things you want to study, contol , measures and manipulate in your sting

# %% [markdown]
# uses of Variable - Lets understand  uses of variable
#
# ## A- Dependent - So what is Dependent Variable  .- Dependent Varible is anything dependent on something else.
#
# Like Example - You Score a Markes . so marks in dependent on your study
#
#
# ## B - Independent - Independent means its not dependent on any things . its goes on. by time.
#
# Like Example - Your Age . is not dependent on any thing day by day you are getting older..
#
#
#
# Different Example-  If you dont study. your marks will dependent on your study . so basically the study is independent and your marks is dependent
#
#
#
# one more example - Hard word lease to sucess . sucess is dependent on your hard word.   hard works depend on you if you working hard . you will get a sucess.

# %% [markdown]
# # 6- Types of Variable continuous and Categorical Variable

# %% [markdown]
# ![image.png](attachment:c3b8abc8-184c-4490-a91d-8f50028071b9.png)

# %% [markdown]
# Types of Variable
# There are Two types of Variable
#
# A- Numerical Variable-
#
#
#
# I->Continous Data- Means there is no limit in the numbers it can be anything .
#
#
#
# -Age-> can be anything
#
#
#
# -Marks-> Marks can be any thing, maybe 0 marks ,1.19 Makrs
#
#
#
# II-> Descrete Data - They are continuous number only,but there it self limitations. this is know as descrete data.
#
#
#
# -Shoe Size - when you go to the shoe shop and ask for 6.8 size . they laugh because shoes size only come in some limitations
#
#
#
# - Rank- Rank is come in like 1,2,3,4... so on . they don't come in 1.25 rank . the have some limitations. is know descrete data.
#
#
#
#
# B- Categorical Variable(String)
#
#
# I-Ordinal Data- The group,the items, the education is in the order.they known as ordinal data
#
#
#
# A-Education level - suppose you are in 7 class and wont jump to the 10 class. there are some order  to follow . this is know an ordianal data.
#
#
#
# II-Nominal Data -Means its just for a name shake .they dont matter much. is known as Nominal Data
#
#
#
# A- Roll number- Your Roll Number is just a number. its not define anything about you. its just a number.
#
#
#
# B- Gender- Gender is only define male or female . its not define the capability of any person. its knows as Nominal Data

# %% [markdown]
# # Descriptive Statistics
#
# 1-Measure of central tendency (Mean,Median,Mode)- A single figure which represent the whole set of data is called an average or measure of central tendency or measure of location. We uses the mean median and mode to describe measure of control tendency.
#
#
#
#
#
# ![image.png](attachment:424b1a34-4759-466b-9044-0eb65e837717.png)
#
#
#
#
# Ex I- suppose in covid time. daily covid cases comes around 35250. what we call, we call daily covid cases increases around 35 k. its is the average of increases of covid cases day per day.
#
#
#
# 2- Measure of Dispersion(Spread)(Variance and Standard Deviation) - Means suppose . i give a 5LPA Salary to you. its maybe called +-50 k and our salary is 4.5 LPA or 5.5 LPA . this is called a measure of dipersion . and how much salary dispersed is 50k its a Standarr Deviation.
#
#
# Variance means. suppose we have salary data of 2 people . and 1st one have 2 LPA and 2nd one have 3LPA
# the variance of 2 people salary is 1 Lakh , if we have lots of salary and then we have to calculate the variance .its a give one number is call variance . its mean how much data varying.

# %%
#What is Variance
import seaborn as sns

a=[1,2,3,4,5,6,4,5,6,7,9,4,5,6,4,5,6,4,6,4,5,6,4,5,6,9,10,11]
sns.scatterplot(a)
# Out:
# <Axes: >

# %%
#What is Standard Deviation
import seaborn as sns
a=[1,2,3,4,5,6,4,5,6,7,9,4,5,6,4,5,6,4,6,4,5,6,4,5,6,9,10,11]
sns.distplot(a)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#For Calculation of Variance There is a formula .
#Measure of dispersion
#x=data,Mu is means, N= occurance

#Lets do that

# %%
import numpy as np
x=[20,34,56]
avg=np.mean(x)
avg
# Out:
# 36.666666666666664

# %%
np.sum((np.square(20-avg)+np.square(34-avg)+np.square(56-avg))/3)
# Out:
# 219.55555555555557

# %%
#Direct Do with a formula to find Variance
import numpy as np

print('Variance',np.var(x))
# Out:
# Variance 219.55555555555557

# %%
#lets find standar deviation using variance

np.sqrt( 219.55555555555557)#its mean the square root of variance is standard deviation
# Out:
# 14.817407180595247

# %%
#Direct find standar deviation with tha formula.

print('Standard Deviation',np.std(x))
# Out:
# Standard Deviation 14.817407180595247

# %% [markdown]
# ![image.png](attachment:a6e17f65-5679-4434-b8e1-04e9ac1b9c2b.png)

# %%
import pandas as pd
#Quantile
y=[10,20,30,40,50,60,70,80]
y_=pd.DataFrame(y)

# %%
y_
# Out:
#     0
# 0  10
# 1  20
# 2  30
# 3  40
# 4  50
# 5  60
# 6  70
# 7  80

# %%
#Lets check describe method its gives a stats of a data 
y_.describe()
# Out:
#                0
# count   8.000000
# mean   45.000000
# std    24.494897
# min    10.000000
# 25%    27.500000
# 50%    45.000000
# 75%    62.500000
# max    80.000000

# %%
#Inter Quantile Range- Q3-Q1
#Quantile Range = max-min
#IQ Range

# %% [markdown]
# # Inferential Statistics
#
# Sampling data and infer the result to describe entire population.

# %% [markdown]
#    # Types of Distribution -
#
#    There are Various types of distribution in statistics . but most commonly used distribution is normal distribution and Z distribution in our course.
#
#
# ![image.png](attachment:7ef10c88-feaa-427d-885c-66af68ac3433.png)
# # Normal Distribution-
#
# A normal distribution is the proper term for a probability bell curve. in a normal distribution the mean is zero and the sandard is ,

# %% [markdown]
# # Skewed Right
# - Means suppose we have a student marks of whole student which are present in class. in class there is 60 student . now we have to check how many student are average and how many student are below average and how many student are getting 100 out of 100.. so what we do. we create a graph. and check .the graph if the graph is skewed in right side . its mean its a skewed right ..
# and as a data scientist we have to make this graph in normal distribution graph.

# %% [markdown]
# # Skewed Left
# -Means suppose we have a student marks of whole student which are present in class. in class there is 60 student . now we have to check how many student are average and how many student are below average and how many student are getting 100 out of 100.. so what we do. we create a graph. and check .the graph if the graph is skewed in left side . its mean its a skewed left ..
# and as a data scientist we have to make this graph in normal distribution graph.

# %% [markdown]
# ## Imp terms
#
# When dealing with data,some machine learning models are designed with the assumption that the data is normally distributed. Based on this assumption, they have designed the algorithm, it is AI/ML engineer responsibility to pass data a data as a normal distributed data ..
#
# if it is not a normal distributed then this is our duty to make it normal. and then pass it to the machine leaning algorithm.
#
# How and all we will discuss !

# %% [markdown]
# # Symmetric Distribution-
# Symmetric Distribution graphs is a perfect graph . and its look like well bell curved. .. and as a data scientist we have to convert all skewed left ,skewed rigth graph to symmetric distribution.
#
#
# suppose in our class 60 students have give exam and like all school and college some student has topper some has below average and maximum are average student. and when we want to create graphs of  class student it will give a bell shaped curve . in our graphs.

# %% [markdown]
# # Uniform Distribution -
# Uniform distribution refers of porbablity distribution in which all outcomes are equally likely.
#
# ### Example- Deck of Cards- Problity of getting only perticular shape and number (1/52)

# %% [markdown]
# # Central Limit Theoram

# %% [markdown]
# - Normal Distribution -Distribution is always normal irrespective of sample size
#
#
# - Non Normal Distribution - If Sample Size is adequate (approximately >30 sample)distribution

# %% [markdown]
# ## Central Limit Theoram
# ### μx̅ = μ                                       (Mean of sample mean = Population mean)
#
# ## To find out the sample standard deviation
#
# ### σx̅ = σ/√n                                 (Population std / sqrt of sample size)

# %% [markdown]
# where
#
#
#
# μ = population mean
#
#
#
# σ = population standar deviation
#
#
#
# μx= Sample mean
#
#
#
# σx = Sample Standard Deviation
#
#
#
# n= Sample Size
#
#
#
# x̅ =Sample Mean

# %% [markdown]
# # HomeWork
#
# ![image.png](attachment:60a55c12-4d53-4822-b5db-86bacb2b9841.png)
#
# ![image.png](attachment:cad2f752-5c36-4fd7-8c32-f6ef7fe85ded.png)

# %% [markdown]
# # Types of Distribution
#
# ![image.png](attachment:1669acbe-387c-4ddf-bfcb-8f5a9da26367.png)

# %%
#AI Engineer - Saurav
#Date - 22 April 2024
#Time - 17:01
